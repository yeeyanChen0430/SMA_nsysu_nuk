# %%
from dcard import Dcard
dcard = Dcard()
ariticle_metas = dcard.forums('exam').get_metas(num=1000, sort='new')
ids = [meta['id'] for meta in ariticle_metas]
articles = dcard.posts(ids).get()
articles = dcard.posts(ariticle_metas).get(comments=True)
article_dict = {}
article_list= []
comment_dict = {}
comment_list =[]





status, fails = posts.download(resources)
print('成功下載！' if len(fails) == 0 else '出了點錯下載不完全喔')
# Out:
# 成功下載！

# %%
import pandas as pd
# my_df = pd.DataFrame(articles.result())
# my_df.to_csv('my_csv_exam.csv')

# %%
import json
from pprint import pprint
# json.loads(ptt['artComments'])
data  = []
for x in range(len(ptt)):
#     print(ptt['artComments'])
#     ptt['artComments'][x] = str(ptt['artComments'][x])
#     print(type(ptt['artComments'])
#     print(ptt['artComments'][x].encode('utf-8'))
#     content
    ptt['artComments'][x]=json.loads(ptt['artComments'][x])
# Out:
# /home/minglun-wu/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df =ptt

# %%
df['artComments'][0]

# %%
len(articles.result())

# %%
df = pd.read_csv("exam_id.csv")
# nsysu = pd.read_csv("my_csv_nsysu.csv")

# %%
# df = pd.merge(nuk_id,nuk,on = 'id',how='left')
# df
nuk_id

# %%
ptt =pd.DataFrame(ptt)
ptt.to_csv("ptt.csv")

# %%
import ast
for index in df["comments"]:
    try:
        df["comments"][index]= ast.literal_eval(index)
    except:
        pass
# print(df)
df_comment = df['comments']
# df.to_csv("comment_nsysu.csv")
# Out:
# /home/minglun-wu/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_comment[0]

# %%
comment_list = []

comment_id = 0
for y in df_comment:
    comment_floor =0
    comment_id+=1
    for x in y:
        try:
#             print(x)
#             print(type(x))
            comment_dict = {}
#             x = ast.literal_eval(x)
            comment_floor+=1
            comment_dict["id"] = comment_id
            comment_dict["floor"] = comment_floor
            comment_dict["content"] = x["content"]
            comment_dict["Date"] = x['createdAt']
            comment_list.append(comment_dict)
        except:
            pass
#         print(x["content"])

# %%
comment_list =pd.DataFrame(comment_list)
comment_list.to_csv("comment_exam.csv")

# %%
comment_list
# Out:
#                           Date  \
# 0     2019-04-11T18:33:11.737Z
# 1     2019-04-11T18:35:09.008Z
# 2     2019-04-11T18:36:19.318Z
# 3     2019-04-11T18:38:11.465Z
# 4     2019-04-11T18:38:13.050Z
# 5     2019-04-11T18:38:47.822Z
# 6     2019-04-11T18:40:43.704Z
# 7     2019-04-11T19:02:12.744Z
# 8     2019-04-11T19:04:54.118Z
# 9     2019-04-11T19:10:29.967Z
# 10    2019-04-11T19:50:33.253Z
# 11    2019-04-11T20:19:38.601Z
# 12    2019-04-11T22:49:46.672Z
# 13    2019-04-11T23:14:57.393Z
# 14    2019-04-12T01:09:34.931Z
# 15    2019-04-12T01:33:56.658Z
# 16    2019-04-12T02:06:32.222Z
# 17    2019-04-12T03:22:03.181Z
# 18    2019-04-12T03:25:01.811Z
# 19    2019-04-12T03:51:15.649Z
# 20    2019-04-12T03:53:01.200Z
# 21    2019-04-12T04:20:10.237Z
# 22    2019-04-12T04:31:31.978Z
# 23    2019-04-12T04:36:45.741Z
# 24    2019-04-12T04:56:21.305Z
# 25    2019-04-12T05:33:58.203Z
# 26    2019-04-12T05:45:56.460Z
# 27    2019-04-12T05:46:08.753Z
# 28    2019-04-12T05:54:50.182Z
# 29    2019-04-12T07:21:15.131Z
# ...                        ...
# 1286  2019-04-04T07:12:23.268Z
# 1287  2019-04-04T07:12:49.579Z
# 1288  2019-04-04T07:13:35.651Z
# 1289  2019-04-04T07:14:53.022Z
# 1290  2019-04-04T07:15:36.148Z
# 1291  2019-04-04T07:15:55.846Z
# 1292  2019-04-04T07:16:33.147Z
# 1293  2019-04-04T07:18:12.871Z
# 1294  2019-04-04T07:19:21.750Z
# 1295  2019-04-04T07:19:45.263Z
# 1296  2019-04-04T07:20:55.313Z
# 1297  2019-04-04T07:21:43.788Z
# 1298  2019-04-04T07:22:08.876Z
# 1299  2019-04-04T07:22:37.184Z
# 1300  2019-04-04T07:24:12.188Z
# 1301  2019-04-04T07:28:44.450Z
# 1302  2019-04-04T07:29:45.466Z
# 1303  2019-04-04T07:39:02.265Z
# 1304  2019-04-04T07:43:50.306Z
# 1305  2019-04-04T08:34:34.642Z
# 1306  2019-04-04T08:53:54.440Z
# 1307  2019-04-04T09:43:15.991Z
# 1308  2019-04-04T10:10:07.725Z
# 1309  2019-04-04T10:41:08.423Z
# 1310  2019-04-04T11:05:32.764Z
# 1311  2019-04-04T19:34:47.397Z
# 1312  2019-04-05T11:26:43.016Z
# 1313  2019-04-05T17:44:01.264Z
# 1314  2019-04-06T19:29:16.951Z
# 1315  2019-04-07T02:27:03.496Z
#
#                                                 content  floor  id
# 0                                                偶支持你重考      1  14
# 1                                  校版發一次這裡又發一次 你是多想戰中山？      2  14
# 2                                          沒人想跟你併的學店生下去      3  14
# 3                                                    廢文      4  14
# 4                                          我還是不懂為何要併這兩間      5  14
# 5                            整天只想無痛升級?\n要是我考上高大我大概已經自殺了      6  14
# 6      我覺得應該是\n\n國立高雄大學=國立高雄大學\n國立中山大學=國立中山大學\n這名字是最好的吧      7  14
# 7                                                不要出來丟臉      8  14
# 8                      重考\n\n然後今天中午是理院併校公聽會\n中山的大家記得去起來      9  14
# 9                                           完蛋以後要變四大三中了     10  14
# 10                                                   下去     11  14
# 11                                  這麼可悲的學歷\n不去唸書還在這邊刷存     12  14
# 12    引戰仔下去\n改名？\n你都不擔心期中考了\n還在乎能不能畢業嗎？\n還擔心畢業證書掛什麼名字嗎？     13  14
# 13                                                 店生嗨嗨     14  14
# 14                                             人不要臉天下無敵     15  14
# 15                                           雄中>中山>高大==     16  14
# 16                                                幫中山QQ     17  14
# 17    幫中山QQ 原本中山機乎等於中央 看到這個就知道中央遠大於中山呵呵 至少我們學校不會找沒聽過...     18  14
# 18                                唯一支持高大糞店自己收攤\n別殘害無辜大學     19  14
# 19                                 國立中山大學校本部\n國立中山大學學店部     20  14
# 20    真的蠻好笑的欸\n明明就是中山一直找別人併校\n然後中山的學生怎麼不去噴高層\n一直攻擊高大...     21  14
# 21    B21 確實沒屁用\n但說實在沒人無聊到敢在期中考週噴教授們吧！\n相信大家期中考壓力都很大...     22  14
# 22    B22 不得否認本校某些人真的蠻低端的\n故意放話引戰\n不過其他校的同學也太容易隨之起舞了...     23  14
# 23                                中山教授很多反對的喔～\n謝謝高大同學關心     24  14
# 24                                      高雄完全大學\n簡稱\n高完大     25  14
# 25                                      高雄人表示，第二個雄中要誕生了     26  14
# 26    B24 很多反對不自己內部處理來戰高大？\n我知道高大有一堆moron\n但中山不是應該智商...     27  14
# 27                              請問這是確定了嗎，，，？\n不是聽說要跟高醫？     28  14
# 28                                   B28 據我所知國私立基本上很難併哦     29  14
# 29                       中嵩大學...至少還保有中字輩，且嵩字代表""山高合併""。     30  14
# ...                                                 ...    ...  ..
# 1286  B292 北大雜系的嗎 我以為實力說是學店生才會說\n\n讓他們開心一下也沒差?把真的付出努...    295  26
# 1287                                  B293\n我們吃米粉，別人在喊熱    296  26
# 1288                              高科和成大醬料對嗆==\n\n有沒有搞錯啊    297  26
# 1289                       B293 B296 不要理他 以同理的角度...拍拍你們    298  26
# 1290                      B295 個人看法 不認同也不需要酸言酸語 理性討論 謝謝    299  26
# 1291                                   還好政大沒這種困擾旁邊只有世新ㄎ    300  26
# 1292                               B300 併校也沒有規定要地理上在附近吧    301  26
# 1293        B300併的話那還得了\n世新最強的傳播無法跟我們傳院比\n這樣根本是我們被完全吃豆腐    302  26
# 1294          B302 你覺得竹教那個系可以跟清大比\n\n就是要吃你豆腐  你有什麼辦法= =    303  26
# 1295               B301 中山跟高雄的合併案應該是基於同一縣市學生數不足萬人的國立大學吧    304  26
# 1296                                   B302 指南山莊要蓋新傳院了呢    305  26
# 1297                    B288 沒上來被砲一下就沒什麼動力，你要不要再補個幾句？哈哈    306  26
# 1298  B303 清大要竹教是因為竹教有藝術跟教育類學科\n世新跟政大科系重疊度幾乎100%\n想不...    307  26
# 1299       B303所以清大狗幹衰啊哈哈\n但至少他們還可以補教育相關的系\n世新完全沒東西給我們補    308  26
# 1300  B308 是說世新也不一定想合併就是了\n別人家族企業學店開很爽\n在台北市區不愁沒學生\n...    309  26
# 1301          B309至少校地不會動輒鬧風波\n或是想裁研究所就隨便裁掉了\n學生應該是滿樂見啦    310  26
# 1302                                           B310 XDD    311  26
# 1303  B306 好了啦同學\n分你沾點喜氣\n明年來當我學弟吧\nhttps://i.imgur....    312  26
# 1304                                B312 電機丙計算機組?\n厲害@@    313  26
# 1305                             B312 好猛!!!\n直接讓瞧不起人的閉嘴    315  26
# 1306    B258 感覺不太可能⋯吧？🤣🤣🤣\n我們學校董事長很佛系經營哈哈哈哈哈\n我 b251 xD    316  26
# 1307                                 B277 可能已經沒魚蝦也好的狀態了    318  26
# 1308                                          都是店有什麼好吵的    319  26
# 1309                            B143 我學測上高雄 果斷指考 給你參考看看    320  26
# 1310                            B319 我們跟台大快合併\n手牽手認親去上課    321  26
# 1311                               高中大+高科大=大高大\n\n高雄起飛囉    323  26
# 1312                                        結論\n地名>>>中字    324  26
# 1313  通報 📢\n好像有人對這篇文章有新想法唷，快來去看看！\n  https://www.dca...    325  26
# 1314                               繼續吵gogo (坐著嗑爆米花中....    326  26
# 1315                                            B143 學店    327  26
#
# [1316 rows x 4 columns]

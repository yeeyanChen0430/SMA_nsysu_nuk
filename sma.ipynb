# %%
from dcard import Dcard
dcard = Dcard()
ariticle_metas = dcard.forums('exam').get_metas(num=1000, sort='new')
ids = [meta['id'] for meta in ariticle_metas]
articles = dcard.posts(ids).get()
articles = dcard.posts(ariticle_metas).get(comments=True)
article_dict = {}
article_list= []
comment_dict = {}
comment_list =[]





status, fails = posts.download(resources)
print('成功下載！' if len(fails) == 0 else '出了點錯下載不完全喔')
# Out:
# 成功下載！

# %%
import pandas as pd
# my_df = pd.DataFrame(articles.result())
# my_df.to_csv('my_csv_exam.csv')

# %%
ptt = pd.read_csv("user4.merge.csv")

# %%
ptt.head(2)
# Out:
#                  InsertDate                       _id     artCat  \
# 0  2019-04-18T17:04:45.344Z  5cb8ae2da525820c30ec025c  Gossiping
# 1  2019-04-18T17:04:45.344Z  5cb8ae2da525820c30ec025d  Gossiping
#
#                                          artComments  \
# 0  [{"cmtStatus": "\u63a8", "cmtPoster": "cytotox...
# 1  [{"cmtStatus": "\u63a8", "cmtPoster": "randy10...
#
#                                           artContent  \
# 0  https://i.imgur.com/ssGYroj.jpg\nhttps://i.img...
# 1  小弟有時候到中山區\n\n路過的男性很多是剛洗完澡的味道\n\n是他們很愛乾淨嗎\n\n有沒...
#
#                     artDate  artIsValid     artPoster                artTitle  \
# 0  2018-09-30T23:21:15.000Z           0  LoveMakeLove  [問卦]中國天安門廣場舉起孫中山巨型肖像的掛
# 1  2018-10-01T01:52:06.000Z           0    soheadsome        [問卦]中山區的男生都很愛乾淨？
#
#                                               artUrl dataSource  \
# 0  https://www.ptt.cc/bbs/Gossiping/M.1538378838....        ptt
# 1  https://www.ptt.cc/bbs/Gossiping/M.1538387890....        ptt
#
#               e_ip
# 0    180.217.187.3
# 1  223.140.100.240

# %%
import json
from pprint import pprint
# json.loads(ptt['artComments'])
data  = []
for x in range(len(ptt)):
#     print(ptt['artComments'])
#     ptt['artComments'][x] = str(ptt['artComments'][x])
#     print(type(ptt['artComments'])
#     print(ptt['artComments'][x].encode('utf-8'))
#     content
    ptt['artComments'][x]=json.loads(ptt['artComments'][x])
# Out:
# /home/minglun-wu/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df =ptt

# %%
df['artComments'][0]
# Out:
# [{'cmtStatus': '推',
#   'cmtPoster': 'cytotoxic',
#   'cmtContent': ':他們歷史是黨說了算',
#   'cmtDate': '2018-10-01 07:21:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'grandwar',
#   'cmtContent': ':孫文像總統府內一直掛著',
#   'cmtDate': '2018-10-01 07:22:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'cytotoxic',
#   'cmtContent': ':哪天黨說毛澤東吃過屎5毛也會推',
#   'cmtDate': '2018-10-01 07:22:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'CavendishJr',
#   'cmtContent': ':中華民族!!!!!中華民族!!!!!經得起',
#   'cmtDate': '2018-10-01 07:22:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'https',
#   'cmtContent': ':以後都到大陸去祭拜',
#   'cmtDate': '2018-10-01 07:22:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'CavendishJr',
#   'cmtContent': ':考驗!!!!!',
#   'cmtDate': '2018-10-01 07:22:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'nakayamayyt',
#   'cmtContent': ':每年都會掛啊',
#   'cmtDate': '2018-10-01 07:22:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'miketk',
#   'cmtContent': ':假鬼假怪三民主義呢?人人投票權呢?',
#   'cmtDate': '2018-10-01 07:22:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':讚兩岸一家親',
#   'cmtDate': '2018-10-01 07:22:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'nakayamayyt',
#   'cmtContent': ':中華人民共和國憲法都寫孫文了',
#   'cmtDate': '2018-10-01 07:22:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'kent',
#   'cmtContent': ':共匪都定義孫文是中國革命先行者了。',
#   'cmtDate': '2018-10-01 07:22:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'ipadmini6',
#   'cmtContent': ':孫文不是台灣國父，ok?',
#   'cmtDate': '2018-10-01 07:22:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'young000',
#   'cmtContent': ':中國的基礎建設基本上也照著建國方略走',
#   'cmtDate': '2018-10-01 07:22:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'miketk',
#   'cmtContent': ':共產黨拜老毛就好了阿.',
#   'cmtDate': '2018-10-01 07:22:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'Dinenger',
#   'cmtContent': ':人家革命領袖也拜託',
#   'cmtDate': '2018-10-01 07:23:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'SayNothing',
#   'cmtContent': ':還說是馬列子孫呢愛怎麼說就怎麼說',
#   'cmtDate': '2018-10-01 07:23:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'z5582143',
#   'cmtContent': ':哈哈哈',
#   'cmtDate': '2018-10-01 07:23:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'Dinenger',
#   'cmtContent': ':毛主席只是比肩蔣光頭的人物',
#   'cmtDate': '2018-10-01 07:23:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'panzerbug',
#   'cmtContent': ':這版本的孫文頭型好像不太一樣',
#   'cmtDate': '2018-10-01 07:23:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'iqeqicq',
#   'cmtContent': ':因為孫大砲主張聯俄容共啊',
#   'cmtDate': '2018-10-01 07:23:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'meredith001',
#   'cmtContent': ':孫文又沒問題掛蔣介石再來吧',
#   'cmtDate': '2018-10-01 07:23:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'nakayamayyt',
#   'cmtContent': ':人家的政府體制才是真正權能區分',
#   'cmtDate': '2018-10-01 07:23:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'Dinenger',
#   'cmtContent': ':長幼有序，不能違反倫理啊',
#   'cmtDate': '2018-10-01 07:23:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'u9005205',
#   'cmtContent': ':阿災！革命先行者國共搶當正統…',
#   'cmtDate': '2018-10-01 07:24:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'louis13',
#   'cmtContent': ':對岸一直以來都不討厭孫文啊他們痛恨的',
#   'cmtDate': '2018-10-01 07:24:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'kudo0930',
#   'cmtContent': ':其實孫文當年是主張國共共存的',
#   'cmtDate': '2018-10-01 07:24:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'louis13',
#   'cmtContent': ':是蔣光頭',
#   'cmtDate': '2018-10-01 07:24:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':我Qooking就是國之瑰寶與革命先行魂',
#   'cmtDate': '2018-10-01 07:24:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'kukuso',
#   'cmtContent': ':這版本是中國毛主席風格嗎XD',
#   'cmtDate': '2018-10-01 07:25:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':你們太弱了',
#   'cmtDate': '2018-10-01 07:25:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'u9005205',
#   'cmtContent': ':從容共抗俄，現在是容共抗台嗎？',
#   'cmtDate': '2018-10-01 07:25:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'alumeya',
#   'cmtContent': ':天安門?',
#   'cmtDate': '2018-10-01 07:26:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'u9005205',
#   'cmtContent': ':國共都在考驗人民的歷史記憶力，然後黑',
#   'cmtDate': '2018-10-01 07:26:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'u9005205',
#   'cmtContent': ':龍轉桌…',
#   'cmtDate': '2018-10-01 07:27:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':支持中國大陸撥亂反正共產黨改成民生黨',
#   'cmtDate': '2018-10-01 07:27:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':中國特色的社會主義寫進我中華民國憲法裡',
#   'cmtDate': '2018-10-01 07:27:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':國民黨改成民族黨民進黨改成民權黨',
#   'cmtDate': '2018-10-01 07:28:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'nakayamayyt',
#   'cmtContent': ':毛澤東還講新三民主義哩',
#   'cmtDate': '2018-10-01 07:28:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':一國上下兩制三民主義不統一',
#   'cmtDate': '2018-10-01 07:28:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'wonder007',
#   'cmtContent': ':蔣就趁孫文死掉後屠殺共產傾向的同志',
#   'cmtDate': '2018-10-01 07:28:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':我Qooking就是國之瑰寶與革命先行魂事業',
#   'cmtDate': '2018-10-01 07:29:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'LarryKu',
#   'cmtContent': ':五權憲法？',
#   'cmtDate': '2018-10-01 07:29:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'walhalla',
#   'cmtContent': ':共產黨的權能區分=有權的一定沒有能XDDD',
#   'cmtDate': '2018-10-01 07:29:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'gameguy',
#   'cmtContent': ':中山橋，蘿莉控，專幹朋友的女兒。1895年',
#   'cmtDate': '2018-10-01 07:30:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'wonder007',
#   'cmtContent': ':可以說共產黨的偏激是蔣催生的',
#   'cmtDate': '2018-10-01 07:30:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'gameguy',
#   'cmtContent': ':台灣人早在當大日本帝國皇民囉',
#   'cmtDate': '2018-10-01 07:30:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'lion198',
#   'cmtContent': ':掛蔣介石才是八卦',
#   'cmtDate': '2018-10-01 07:30:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':孫文是個紳士不要忌妒不許亂說',
#   'cmtDate': '2018-10-01 07:31:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'eric999',
#   'cmtContent': ':原Po26還裝蒜，明明老共年年都會掛。',
#   'cmtDate': '2018-10-01 07:32:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'eric999',
#   'cmtContent': ':其實唐德剛書中寫過，目前維持了快一百',
#   'cmtDate': '2018-10-01 07:34:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'eric999',
#   'cmtContent': ':年兩個中國的困境，始作俑者是孫大砲。',
#   'cmtDate': '2018-10-01 07:34:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':現代人少見多怪古時候很多都年輕就嫁了',
#   'cmtDate': '2018-10-01 07:34:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'bearq258',
#   'cmtContent': ':1895孫文也拿過日本護照廣義皇民',
#   'cmtDate': '2018-10-01 07:35:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'user1001',
#   'cmtContent': ":孫文是革命'先行者',不是中共國父,就像",
#   'cmtDate': '2018-10-01 07:35:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'user1001',
#   'cmtContent': ':台灣人跟原住民的差別',
#   'cmtDate': '2018-10-01 07:35:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'eric999',
#   'cmtContent': ':主因在孫文提拔過當時鳥蛋都不是的毛潤',
#   'cmtDate': '2018-10-01 07:35:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'eric999',
#   'cmtContent': ':之。後來毛潤之變毛主席，自然會覺得孫',
#   'cmtDate': '2018-10-01 07:35:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'eric999',
#   'cmtContent': ':總理眼光過人，不愧一代偉人。',
#   'cmtDate': '2018-10-01 07:36:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'eric999',
#   'cmtContent': ':而且是破格提拔。',
#   'cmtDate': '2018-10-01 07:36:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'Seiran',
#   'cmtContent': ':公關業者帶風向膩',
#   'cmtDate': '2018-10-01 07:37:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'eterbless',
#   'cmtContent': ':你是不知道共產黨也捧大炮當國父嗎',
#   'cmtDate': '2018-10-01 07:38:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'eric999',
#   'cmtContent': ':用日本名字娶日本老婆生日本女兒，真',
#   'cmtDate': '2018-10-01 07:38:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'eric999',
#   'cmtContent': ':皇民無誤。',
#   'cmtDate': '2018-10-01 07:38:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':共產黨覺得他們自己是思想繼承者',
#   'cmtDate': '2018-10-01 07:38:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'eric999',
#   'cmtContent': ':革命先行者啦，共和國沒有國父',
#   'cmtDate': '2018-10-01 07:39:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':國民黨覺得他們是事業繼承者',
#   'cmtDate': '2018-10-01 07:39:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'mpyhacct0443',
#   'cmtContent': ':三民主義三權分立呢假中國真支那',
#   'cmtDate': '2018-10-01 07:40:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'blackone979',
#   'cmtContent': ':以今天老共的說法孫文就是精日分子',
#   'cmtDate': '2018-10-01 07:40:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':原因在於國之瑰寶後來選擇留在中國大陸',
#   'cmtDate': '2018-10-01 07:40:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'eric999',
#   'cmtContent': ':主要是孫大砲最後一個老婆後來投共反蔣',
#   'cmtDate': '2018-10-01 07:40:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'eric999',
#   'cmtContent': ':，給共產黨增威過。',
#   'cmtDate': '2018-10-01 07:40:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':我個人是這麼覺得啦',
#   'cmtDate': '2018-10-01 07:40:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'akiue',
#   'cmtContent': ':不就自助餐，想繼承中華民國，又不想三民主',
#   'cmtDate': '2018-10-01 07:41:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'akiue',
#   'cmtContent': ':義。',
#   'cmtDate': '2018-10-01 07:41:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':我才不想講什麼左派右派都太極端了',
#   'cmtDate': '2018-10-01 07:41:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'homeaki',
#   'cmtContent': ':孫文美國人',
#   'cmtDate': '2018-10-01 07:41:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'php4',
#   'cmtContent': ':掛起蘿莉控兼賣國者了',
#   'cmtDate': '2018-10-01 07:42:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'eric999',
#   'cmtContent': ':笑，不懂就說別人極端。',
#   'cmtDate': '2018-10-01 07:42:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'awoorog',
#   'cmtContent': ':孫中山看到現在的支那有皇帝不知道作何感',
#   'cmtDate': '2018-10-01 07:43:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'awoorog',
#   'cmtContent': ':想',
#   'cmtDate': '2018-10-01 07:43:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'willy61615',
#   'cmtContent': ':連自己國父都丟掉的鬼島肯定沒有未',
#   'cmtDate': '2018-10-01 07:43:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'willy61615',
#   'cmtContent': ':來',
#   'cmtDate': '2018-10-01 07:43:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'Qooking',
#   'cmtContent': ':我覺得照我的觀點比較soft..youknow',
#   'cmtDate': '2018-10-01 07:44:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'akiue',
#   'cmtContent': ':孫真的想當國父？其他革命人士都空氣。',
#   'cmtDate': '2018-10-01 07:47:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'iqeqicq',
#   'cmtContent': ':是蔣封孫為國父的，只憑一張黨內命令',
#   'cmtDate': '2018-10-01 07:50:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'willy61615',
#   'cmtContent': ':如果孫不夠格當國父自然有人出來反對',
#   'cmtDate': '2018-10-01 07:54:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'willy61615',
#   'cmtContent': ':而竟然大家都對孫沒意見那是誰先稱',
#   'cmtDate': '2018-10-01 07:54:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'willy61615',
#   'cmtContent': ':孫為國父根本一點都不重要',
#   'cmtDate': '2018-10-01 07:54:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'etiennechiu',
#   'cmtContent': ':中國他們叫孫文為革命先行者',
#   'cmtDate': '2018-10-01 07:55:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'etiennechiu',
#   'cmtContent': ':他們敢掛孫文因為沒什麼，但不敢掛',
#   'cmtDate': '2018-10-01 07:56:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'etiennechiu',
#   'cmtContent': ':蔣',
#   'cmtDate': '2018-10-01 07:56:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'pili20934',
#   'cmtContent': ':閻孝國表示',
#   'cmtDate': '2018-10-01 08:00:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'forest204c',
#   'cmtContent': ':哪天掛蔣光頭在說，井底蛙',
#   'cmtDate': '2018-10-01 08:01:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'haoyin0105',
#   'cmtContent': ':中國的國父也是孫文',
#   'cmtDate': '2018-10-01 08:04:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'mhfo3035',
#   'cmtContent': ':井蛙',
#   'cmtDate': '2018-10-01 08:07:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'maxto1977',
#   'cmtContent': ':戀童癖的照片被放大了',
#   'cmtDate': '2018-10-01 08:08:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'erikanofann',
#   'cmtContent': ':共產黨也尊他啊井蛙',
#   'cmtDate': '2018-10-01 08:08:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'dyps',
#   'cmtContent': ':我們國父崇尚蘿莉',
#   'cmtDate': '2018-10-01 08:08:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'cms6384',
#   'cmtContent': ':大膽居然不是掛偉大的習大大的畫像',
#   'cmtDate': '2018-10-01 08:09:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'SupCat',
#   'cmtContent': ':關臺灣屁事',
#   'cmtDate': '2018-10-01 08:10:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'ororzzz',
#   'cmtContent': ':你第一天知道喔？',
#   'cmtDate': '2018-10-01 08:18:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'KaiManSo',
#   'cmtContent': ':怎麼不P圖一個蘿莉陪他？',
#   'cmtDate': '2018-10-01 08:26:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'GanKer',
#   'cmtContent': ':突然把孫文搬出來~怪怪的……',
#   'cmtDate': '2018-10-01 08:29:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'GanKer',
#   'cmtContent': ':中國真是個怪地方~',
#   'cmtDate': '2018-10-01 08:29:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'KaiManSo',
#   'cmtContent': ':放毛賊東還是比較不違和',
#   'cmtDate': '2018-10-01 08:30:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'L9C4iO',
#   'cmtContent': ':把天安門那土匪照片拆掉再叫我',
#   'cmtDate': '2018-10-01 08:31:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'aph860212',
#   'cmtContent': ':蘿莉萬歲',
#   'cmtDate': '2018-10-01 08:35:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'BlackBass',
#   'cmtContent': ':支那滾',
#   'cmtDate': '2018-10-01 08:38:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'nodnod',
#   'cmtContent': ':台灣國又不存在當然沒有台灣國父',
#   'cmtDate': '2018-10-01 08:39:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'Fice',
#   'cmtContent': ':文革餘孽沾什麼光',
#   'cmtDate': '2018-10-01 08:40:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'cradredtade',
#   'cmtContent': ':蘿莉控',
#   'cmtDate': '2018-10-01 08:48:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'sa250135',
#   'cmtContent': ':井蛙第一天知道阿',
#   'cmtDate': '2018-10-01 09:16:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'herculex',
#   'cmtContent': ':孫文喜歡共產黨，民生主義就是共產主義',
#   'cmtDate': '2018-10-01 09:22:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'herculex',
#   'cmtContent': ':孫文自己講過的話，當然讓共產黨巴著',
#   'cmtDate': '2018-10-01 09:24:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'imhank',
#   'cmtContent': ':掛孫文還不是都是為了鞏固政權',
#   'cmtDate': '2018-10-01 10:12:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'imhank',
#   'cmtContent': ':不然平常也沒人想理只是做樣子罷了',
#   'cmtDate': '2018-10-01 10:12:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'yuinghoooo',
#   'cmtContent': ':台灣國父不是岩里政男嗎',
#   'cmtDate': '2018-10-01 10:27:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'apenguin',
#   'cmtContent': ':聽你在胡扯只聽過要除掉蔣公像可沒聽',
#   'cmtDate': '2018-10-01 10:34:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'apenguin',
#   'cmtContent': ':過要除掉孫中山的你是五毛嗎?',
#   'cmtDate': '2018-10-01 10:34:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'Sinkage',
#   'cmtContent': ':孫文就是個把當時流行思想一大抄的草包',
#   'cmtDate': '2018-10-01 10:52:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'Sinkage',
#   'cmtContent': ':阿社會主義當年這麼潮他當然愛共產',
#   'cmtDate': '2018-10-01 10:52:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'seal81924',
#   'cmtContent': ':這id就是9.2阿',
#   'cmtDate': '2018-10-01 12:00:00+00:00'},
#  {'cmtStatus': '推',
#   'cmtPoster': 'amoe1210',
#   'cmtContent': ':我記得天安門本來就有',
#   'cmtDate': '2018-10-01 13:50:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'jay0215',
#   'cmtContent': ':DPP:外國國父',
#   'cmtDate': '2018-10-01 15:53:00+00:00'},
#  {'cmtStatus': '噓',
#   'cmtPoster': 'jake255121',
#   'cmtContent': ':所以呢',
#   'cmtDate': '2018-10-02 02:39:00+00:00'},
#  {'cmtStatus': '→',
#   'cmtPoster': 'vasia',
#   'cmtContent': ':孫中山推行的民主國家呢？',
#   'cmtDate': '2018-10-02 02:51:00+00:00'}]

# %%
len(articles.result())

# %%
df = pd.read_csv("nuk_id.csv")
# nsysu = pd.read_csv("my_csv_nsysu.csv")

# %%
# df = pd.merge(nuk_id,nuk,on = 'id',how='left')
# df
nuk_id

# %%
ptt =pd.DataFrame(ptt)
ptt.to_csv("ptt.csv")

# %%
import ast
for index in df["comments"]:
    try:
        df["comments"][index]= ast.literal_eval(index)
    except:
        pass
# print(df)
df_comment = df['comments']
# df.to_csv("comment_nsysu.csv")
# Out:
# /home/minglun-wu/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_comment[0]
# Out:
# "[{'id': '25a121ea-3f8c-4fd3-89df-e2374fd6e4d4', 'anonymous': False, 'postId': 231094860, 'createdAt': '2019-04-15T13:06:40.733Z', 'updatedAt': '2019-04-15T13:06:40.733Z', 'floor': 1, 'content': '引戰的味道', 'likeCount': 6, 'withNickname': False, 'hiddenByAuthor': False, 'gender': 'M', 'school': '國立高雄大學', 'department': '電機工程學系', 'host': False, 'reportReason': '', 'mediaMeta': [], 'hidden': False, 'inReview': False, 'postAvatar': ''}, {'id': '0696de03-e1e1-4f75-aa09-0002dd696cdb', 'anonymous': True, 'postId': 231094860, 'createdAt': '2019-04-15T13:06:56.967Z', 'updatedAt': '2019-04-15T13:06:56.967Z', 'floor': 2, 'content': '我轉出去 又轉回來了', 'likeCount': 6, 'withNickname': False, 'hiddenByAuthor': False, 'gender': 'M', 'school': '國立高雄大學', 'host': False, 'reportReason': '', 'mediaMeta': [], 'hidden': False, 'inReview': False, 'postAvatar': ''}, {'id': 'f3fff08f-0cdb-45bf-a40d-9dd6c432e918', 'anonymous': True, 'postId': 231094860, 'createdAt': '2019-04-15T13:08:30.037Z', 'updatedAt': '2019-04-15T16:03:14.424Z', 'floor': 3, 'content': 'B1 \\n我轉過去就可以學中山猴子仔崩潰\\n反串成中山戰你們了', 'likeCount': 6, 'withNickname': False, 'hiddenByAuthor': False, 'gender': 'M', 'school': '國立高雄大學', 'host': True, 'reportReason': '', 'mediaMeta': [], 'hidden': False, 'inReview': False, 'postAvatar': ''}, {'id': 'e8e83230-0d1e-48f6-b560-dcb2321d5de8', 'anonymous': False, 'postId': 231094860, 'createdAt': '2019-04-15T13:13:14.406Z', 'updatedAt': '2019-04-15T14:56:10.253Z', 'floor': 4, 'content': '你轉過去就是中山學生 不算反串了啊\\n\\n我看你還是別浪費報名費ㄌ', 'likeCount': 1, 'withNickname': False, 'hiddenByAuthor': False, 'gender': 'M', 'school': '國立高雄大學', 'department': '電機工程學系', 'host': False, 'reportReason': '', 'mediaMeta': [], 'hidden': False, 'inReview': False, 'postAvatar': ''}, {'id': '0a0eb770-384a-492b-b5e6-544c86289436', 'anonymous': True, 'postId': 231094860, 'createdAt': '2019-04-15T13:54:50.116Z', 'updatedAt': '2019-04-15T13:54:50.116Z', 'floor': 5, 'content': '啊！不廢話了 反正我考不上中山', 'likeCount': 1, 'withNickname': False, 'hiddenByAuthor': False, 'gender': 'M', 'school': '國立高雄大學', 'host': True, 'reportReason': '', 'mediaMeta': [], 'hidden': False, 'inReview': False, 'postAvatar': ''}, {'id': 'dc87101f-c5e6-4d76-ab18-3356ca6454a5', 'anonymous': False, 'postId': 231094860, 'createdAt': '2019-04-15T13:56:10.604Z', 'updatedAt': '2019-04-15T13:56:10.604Z', 'floor': 6, 'content': '考上去然後嘴高大阿  ㄏㄏ', 'likeCount': 2, 'withNickname': False, 'hiddenByAuthor': False, 'gender': 'M', 'school': '國立高雄大學', 'department': '電機工程學系', 'host': False, 'reportReason': '', 'mediaMeta': [], 'hidden': False, 'inReview': False, 'postAvatar': ''}, {'id': '8081d26b-d559-4b1e-81d1-6f59bd91b774', 'anonymous': False, 'postId': 231094860, 'createdAt': '2019-04-15T16:06:55.969Z', 'updatedAt': '2019-04-15T16:08:02.090Z', 'floor': 7, 'content': '快考不然以後畢業證書寫中山大學楠梓校區很難解釋\\n講自己中山大學\\n「他媽的拉基學店仔裝自己中山大學喔」\\n講自己高雄大學\\n「他媽的拉基學店仔是還有高大喔佔了便宜還賣乖」\\n可憐喔QQ', 'likeCount': 3, 'withNickname': False, 'hiddenByAuthor': False, 'gender': 'M', 'school': '國立高雄大學', 'department': '電機工程學系', 'host': False, 'reportReason': '', 'mediaMeta': [], 'hidden': False, 'inReview': False, 'postAvatar': ''}, {'id': '68f4ca90-631c-438e-baf9-15a4e89f4557', 'anonymous': True, 'postId': 231094860, 'createdAt': '2019-04-16T02:36:25.384Z', 'updatedAt': '2019-04-16T02:36:25.384Z', 'floor': 8, 'content': '講的好像很好考一樣幹', 'likeCount': 0, 'withNickname': False, 'hiddenByAuthor': False, 'gender': 'F', 'school': '國立高雄大學', 'host': False, 'reportReason': '', 'mediaMeta': [], 'hidden': False, 'inReview': False, 'postAvatar': ''}, {'id': 'f41949f6-415a-42a4-a37d-1d01f5f44a56', 'anonymous': True, 'postId': 231094860, 'createdAt': '2019-04-16T12:52:54.663Z', 'updatedAt': '2019-04-16T12:52:54.663Z', 'floor': 9, 'content': '下去領五塊', 'likeCount': 0, 'withNickname': False, 'hiddenByAuthor': False, 'gender': 'M', 'school': '國立高雄大學', 'host': False, 'reportReason': '', 'mediaMeta': [], 'hidden': False, 'inReview': False, 'postAvatar': ''}, {'id': '5447e287-c632-4acb-8f49-c306d6cbab90', 'anonymous' ...

# %%
comment_list = []

comment_id = 0
for y in df_comment:
    comment_floor =0
    comment_id+=1
    for x in y:
        try:
#             print(x)
#             print(type(x))
            comment_dict = {}
#             x = ast.literal_eval(x)
            comment_floor+=1
            comment_dict["id"] = comment_id
            comment_dict["floor"] = comment_floor
            comment_dict["content"] = x["content"]
            comment_dict["Date"] = x['createdAt']
            comment_list.append(comment_dict)
        except:
            pass
#         print(x["content"])

# %%
comment_list =pd.DataFrame(comment_list)
comment_list.to_csv("comment_nuk.csv")

# %%
comment_list
# Out:
#                          Date  \
# 0    2019-04-15T13:06:40.733Z
# 1    2019-04-15T13:06:56.967Z
# 2    2019-04-15T13:08:30.037Z
# 3    2019-04-15T13:13:14.406Z
# 4    2019-04-15T13:54:50.116Z
# 5    2019-04-15T13:56:10.604Z
# 6    2019-04-15T16:06:55.969Z
# 7    2019-04-16T02:36:25.384Z
# 8    2019-04-16T12:52:54.663Z
# 9    2019-04-16T13:46:39.810Z
# 10   2019-04-14T10:05:42.010Z
# 11   2019-04-14T10:19:21.827Z
# 12   2019-04-14T10:36:51.839Z
# 13   2019-04-14T11:33:39.380Z
# 14   2019-04-14T11:53:21.126Z
# 15   2019-04-14T12:08:59.069Z
# 16   2019-04-14T12:32:57.681Z
# 17   2019-04-14T12:37:38.427Z
# 18   2019-04-14T13:02:13.437Z
# 19   2019-04-14T15:16:20.238Z
# 20   2019-04-14T17:05:26.364Z
# 21   2019-04-14T22:57:55.550Z
# 22   2019-04-13T20:28:30.992Z
# 23   2019-04-13T21:45:10.885Z
# 24   2019-04-13T23:15:38.379Z
# 25   2019-04-14T02:58:39.137Z
# 26   2019-04-14T04:25:22.479Z
# 27   2019-04-14T04:29:02.725Z
# 28   2019-04-14T04:29:25.199Z
# 29   2019-04-14T07:30:52.956Z
# ..                        ...
# 788  2018-12-09T08:21:50.086Z
# 789  2018-12-09T08:43:39.311Z
# 790  2018-12-09T10:20:29.610Z
# 791  2018-12-09T15:29:59.502Z
# 792  2018-12-09T16:01:03.085Z
# 793  2018-12-09T16:22:22.605Z
# 794  2018-11-26T15:19:52.127Z
# 795  2018-11-27T04:35:09.507Z
# 796  2018-11-27T15:33:11.426Z
# 797  2018-11-26T10:39:42.077Z
# 798  2018-11-26T11:06:19.212Z
# 799  2018-11-26T11:19:37.243Z
# 800  2018-11-26T11:27:14.830Z
# 801  2018-11-26T11:30:58.651Z
# 802  2018-11-26T12:02:19.622Z
# 803  2018-11-26T14:49:33.063Z
# 804  2018-11-26T15:13:06.460Z
# 805  2018-11-26T15:56:51.366Z
# 806  2018-11-26T15:58:27.385Z
# 807  2018-11-18T03:02:24.399Z
# 808  2018-11-18T03:15:21.612Z
# 809  2018-11-18T03:38:11.515Z
# 810  2018-11-18T03:39:52.441Z
# 811  2018-11-18T03:41:58.640Z
# 812  2018-11-18T03:58:25.954Z
# 813  2018-11-18T04:24:28.500Z
# 814  2018-11-20T01:35:52.320Z
# 815  2018-11-20T02:14:44.967Z
# 816  2018-11-20T05:13:21.984Z
# 817  2018-11-20T09:02:19.974Z
#
#                                                content  floor  id
# 0                                                引戰的味道      1  36
# 1                                           我轉出去 又轉回來了      2  36
# 2                      B1 \n我轉過去就可以學中山猴子仔崩潰\n反串成中山戰你們了      3  36
# 3                    你轉過去就是中山學生 不算反串了啊\n\n我看你還是別浪費報名費ㄌ      4  36
# 4                                      啊！不廢話了 反正我考不上中山      5  36
# 5                                        考上去然後嘴高大阿  ㄏㄏ      6  36
# 6    快考不然以後畢業證書寫中山大學楠梓校區很難解釋\n講自己中山大學\n「他媽的拉基學店仔裝自己...      7  36
# 7                                           講的好像很好考一樣幹      8  36
# 8                                                下去領五塊      9  36
# 9                                 自己的學校都拿來消費了 我看也沒前途了吧     10  36
# 10                                        乾泥良擊敗 嚇死誰啊 乾      1  37
# 11                                               樓上撿到槍      2  37
# 12                                                  過氣      3  37
# 13                                                  笑死      4  37
# 14                                            乾爹的老母雞白蘭      5  37
# 15                                            一人一把槍對開啊      6  37
# 16                                            還以為是光頭哥哥      7  37
# 17                                            感謝期中好運阿鐘      8  37
# 18                                                   幹      9  37
# 19                                               b9 趴好     10  37
# 20                     https://i.imgur.com/uO5sgjV.jpg     11  37
# 21                                       B11 我沒過絕對肛死ㄋ啦     12  37
# 22                      就當作是買帳引戰的吧\n四大這種素質zzz\n尤其是成大那個      1  38
# 23   現在在學的畢業也是會備註原高雄大學\n\n就算沒有，面試成績單一拿出來別人也知道你那間學校出...      2  38
# 24   別難過，真的併校後受益的也不會是現在的在校生，所以邏輯不正常的人都不需要為他們的話語生氣。\...      3  38
# 25                                          低能卡猶如照妖鏡般～      4  38
# 26   — 高大學生想併校 —\n他媽的垃圾學店，可以不要和這種學校併校嗎？ 我考那麼高分不是想和他...      5  38
# 27   說真的學歷升級學生當然會高興，但還是會註記其實根本對就業時沒差\n\n看他們校版之前有跟台大...      6  38
# 28                      B5 你知道的太多了😂\n反正被併怎麼講錯的都是高大學生QQ      7  38
# 29                              我們學校什麼時候開學生的公聽會啊？還是不開？      8  38
# ..                                                 ...    ...  ..
# 788                                      你的幽默感downdown     14  66
# 789                                                好爽ㄛ     15  66
# 790                                       484該灌爆教育部信箱啊     16  66
# 791                             B12 系上教授說的\n你覺得可信度...？     17  66
# 792                                        戰到300多樓啊好刺激     18  66
# 793                                       收工了 收工了 大家散吧     19  66
# 794                         高大要成為\n升學率（X \n生育率（O 最高的學府      2  67
# 795                                        我大高大乃南部第一學府      3  67
# 796                           期待愛愛摩天輪\n每天我都要去\n不要食言啦韓總      4  67
# 797      不管啦 韓總要帶我們賺大錢欸\n陸生不來 高大永遠爬不起來啦\n爹親娘親都沒有韓總親 懂？      1  68
# 798  什麼合併\n統一就統一\n不想被壓著打就只有兩條路走\n一是起身反抗\n二是跪著接受\n多數...      2  68
# 799  B2 我猜我們根本不能打ㄅ\n直接投降\n對面一人吐一口水就淹死我們了\n只是希望等我們畢業...      3  68
# 800                         學生進得來!人才出的去! 校友賺大錢! 高大發大財!      4  68
# 801                                          怎麼一堆輸不起的阿      5  68
# 802                             反抗就吃子彈\n跪著就繼續活   就這麼簡單      6  68
# 803                                    我怎麼想都覺得法學院會先被炸爛      7  68
# 804                                      要吃子彈也得共軍登島戰成功      8  68
# 805                            B8 感覺不是很難喔\n而且有先鋒部隊非洲豬瘟      9  68
# 806  B9 \n我對我們的邊境檢疫人員有信心\n但對那些真的很想讓台灣沒豬肉可吃的垃圾中共同路人很沒信心     10  68
# 807                                              再不戴套阿      1  69
# 808                                           少一個世界更美好      2  69
# 809                                            你腦袋才有病吧      3  69
# 810   B3 太激動了啦，肛交等於同性戀嗎？不要對號入座啦，這是疾病署的研究，只是呼籲，可是沒有歧視喔~      4  69
# 811                                  貼個事實都可以爆氣\n厲害了我的姐      5  69
# 812                                        b3 77777777      6  69
# 813                                         有人知道 fist…      7  69
# 814                                   世界上如果沒有同性戀就沒有愛滋病      8  69
# 815                               B8 世界上如果沒有你 平均智商就會提高      9  69
# 816                                           B9 幹我快笑死     10  69
# 817  兩個沒愛滋的人進行肛交是不會有愛滋的喔\n恐怖的不是肛交，是自知帶有愛滋還跟別人從事不安全性...     11  69
#
# [818 rows x 4 columns]

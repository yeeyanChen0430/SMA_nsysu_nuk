# %%
from dcard import Dcard
dcard = Dcard()
ariticle_metas = dcard.forums('exam').get_metas(num=1000, sort='new')
ids = [meta['id'] for meta in ariticle_metas]
articles = dcard.posts(ids).get()
articles = dcard.posts(ariticle_metas).get(comments=True)
article_dict = {}
article_list= []
comment_dict = {}
comment_list =[]





status, fails = posts.download(resources)
print('成功下載！' if len(fails) == 0 else '出了點錯下載不完全喔')
# Out:
# 成功下載！

# %%
import pandas as pd
# my_df = pd.DataFrame(articles.result())
# my_df.to_csv('my_csv_exam.csv')

# %%
import json
from pprint import pprint
# json.loads(ptt['artComments'])
data  = []
for x in range(len(ptt)):
#     print(ptt['artComments'])
#     ptt['artComments'][x] = str(ptt['artComments'][x])
#     print(type(ptt['artComments'])
#     print(ptt['artComments'][x].encode('utf-8'))
#     content
    ptt['artComments'][x]=json.loads(ptt['artComments'][x])
# Out:
# /home/minglun-wu/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df =ptt

# %%
df['artComments'][0]

# %%
len(articles.result())

# %%
import pandas as pd
df = pd.read_csv("ptt_id.csv")
# nsysu = pd.read_csv("my_csv_nsysu.csv")

# %%
# ptt =pd.DataFrame(ptt)
# ptt.to_csv("ptt.csv")
df

# %%
import ast
for index in df["artComments"]:
    try:
        df["artComments"][index]= ast.literal_eval(index)
    except:
        pass
# print(df)

df_comment = df[['_id','artComments']]
# df.to_csv("comment_nsysu.csv")
# Out:
# /home/minglun-wu/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_comment['artComments'][0]

# %%
comment_list = []
comment_id = 0
for index,y in df_comment.iterrows():
    try:
        comment_floor =0
        y['artComments'] = ast.literal_eval(y['artComments'])
        for x in y['artComments']:

                comment_dict = {}
    #             print(x)
                comment_floor+=1
                comment_dict["id"] = y['_id']
                comment_dict["floor"] = comment_floor
                comment_dict["content"] = x["artContent"]
                comment_dict["Date"] = x['art']
                comment_list.append(comment_dict)
    except:
#             print("123")
        pass
#         print(x["content"])

# %%
comment_list =pd.DataFrame(comment_list)
comment_list.to_csv("comment_exam.csv")

# %%
comment_list
# Out:
#                          Date  \
# 0    2019-04-11T18:33:11.737Z
# 1    2019-04-11T18:35:09.008Z
# 2    2019-04-11T18:36:19.318Z
# 3    2019-04-11T18:38:11.465Z
# 4    2019-04-11T18:38:13.050Z
# 5    2019-04-11T18:38:47.822Z
# 6    2019-04-11T18:40:43.704Z
# 7    2019-04-11T19:02:12.744Z
# 8    2019-04-11T19:04:54.118Z
# 9    2019-04-11T19:10:29.967Z
# 10   2019-04-11T19:50:33.253Z
# 11   2019-04-11T20:19:38.601Z
# 12   2019-04-11T22:49:46.672Z
# 13   2019-04-11T23:14:57.393Z
# 14   2019-04-12T01:09:34.931Z
# 15   2019-04-12T01:33:56.658Z
# 16   2019-04-12T02:06:32.222Z
# 17   2019-04-12T03:22:03.181Z
# 18   2019-04-12T03:25:01.811Z
# 19   2019-04-12T03:51:15.649Z
# 20   2019-04-12T03:53:01.200Z
# 21   2019-04-12T04:20:10.237Z
# 22   2019-04-12T04:31:31.978Z
# 23   2019-04-12T04:36:45.741Z
# 24   2019-04-12T04:56:21.305Z
# 25   2019-04-12T05:33:58.203Z
# 26   2019-04-12T05:45:56.460Z
# 27   2019-04-12T05:46:08.753Z
# 28   2019-04-12T05:54:50.182Z
# 29   2019-04-12T07:21:15.131Z
# ..                        ...
# 288  2019-04-04T12:16:46.307Z
# 289  2019-04-04T13:06:25.375Z
# 290  2019-04-04T13:55:39.532Z
# 291  2019-04-04T14:31:33.838Z
# 292  2019-04-04T14:38:00.863Z
# 293  2019-04-04T15:33:28.521Z
# 294  2019-04-04T16:09:43.469Z
# 295  2019-04-04T16:56:04.861Z
# 296  2019-04-04T16:58:15.204Z
# 297  2019-04-04T16:59:34.680Z
# 298  2019-04-04T17:23:31.126Z
# 299  2019-04-04T17:39:10.324Z
# 300  2019-04-04T18:17:25.184Z
# 301  2019-04-04T20:05:30.995Z
# 302  2019-04-04T21:44:06.869Z
# 303  2019-04-04T23:29:18.543Z
# 304  2019-04-05T00:06:47.434Z
# 305  2019-04-02T18:13:48.401Z
# 306  2019-04-02T18:15:52.868Z
# 307  2019-04-02T18:20:55.941Z
# 308  2019-04-02T18:57:35.166Z
# 309  2019-04-02T19:09:09.352Z
# 310  2019-04-02T19:29:57.290Z
# 311  2019-04-02T19:34:20.490Z
# 312  2019-04-02T19:39:40.998Z
# 313  2019-04-02T20:04:47.048Z
# 314  2019-04-02T21:29:29.392Z
# 315  2019-04-02T22:54:51.983Z
# 316  2019-04-02T23:28:33.566Z
# 317  2019-04-03T00:22:24.581Z
#
#                                                content  floor         id
# 0                                               偶支持你重考      1  231070241
# 1                                 校版發一次這裡又發一次 你是多想戰中山？      2  231070241
# 2                                         沒人想跟你併的學店生下去      3  231070241
# 3                                                   廢文      4  231070241
# 4                                         我還是不懂為何要併這兩間      5  231070241
# 5                           整天只想無痛升級?\n要是我考上高大我大概已經自殺了      6  231070241
# 6     我覺得應該是\n\n國立高雄大學=國立高雄大學\n國立中山大學=國立中山大學\n這名字是最好的吧      7  231070241
# 7                                               不要出來丟臉      8  231070241
# 8                     重考\n\n然後今天中午是理院併校公聽會\n中山的大家記得去起來      9  231070241
# 9                                          完蛋以後要變四大三中了     10  231070241
# 10                                                  下去     11  231070241
# 11                                 這麼可悲的學歷\n不去唸書還在這邊刷存     12  231070241
# 12   引戰仔下去\n改名？\n你都不擔心期中考了\n還在乎能不能畢業嗎？\n還擔心畢業證書掛什麼名字嗎？     13  231070241
# 13                                                店生嗨嗨     14  231070241
# 14                                            人不要臉天下無敵     15  231070241
# 15                                          雄中>中山>高大==     16  231070241
# 16                                               幫中山QQ     17  231070241
# 17   幫中山QQ 原本中山機乎等於中央 看到這個就知道中央遠大於中山呵呵 至少我們學校不會找沒聽過...     18  231070241
# 18                               唯一支持高大糞店自己收攤\n別殘害無辜大學     19  231070241
# 19                                國立中山大學校本部\n國立中山大學學店部     20  231070241
# 20   真的蠻好笑的欸\n明明就是中山一直找別人併校\n然後中山的學生怎麼不去噴高層\n一直攻擊高大...     21  231070241
# 21   B21 確實沒屁用\n但說實在沒人無聊到敢在期中考週噴教授們吧！\n相信大家期中考壓力都很大...     22  231070241
# 22   B22 不得否認本校某些人真的蠻低端的\n故意放話引戰\n不過其他校的同學也太容易隨之起舞了...     23  231070241
# 23                               中山教授很多反對的喔～\n謝謝高大同學關心     24  231070241
# 24                                     高雄完全大學\n簡稱\n高完大     25  231070241
# 25                                     高雄人表示，第二個雄中要誕生了     26  231070241
# 26   B24 很多反對不自己內部處理來戰高大？\n我知道高大有一堆moron\n但中山不是應該智商...     27  231070241
# 27                             請問這是確定了嗎，，，？\n不是聽說要跟高醫？     28  231070241
# 28                                  B28 據我所知國私立基本上很難併哦     29  231070241
# 29                      中嵩大學...至少還保有中字輩，且嵩字代表""山高合併""。     30  231070241
# ..                                                 ...    ...        ...
# 288                           B18 偉哉淡江學店\n資產只輸那些醫學類的大學     20  231020580
# 289                                       我們默默的當學店生就好😊     21  231020580
# 290                                       國北教 ? 國立後段 ?     22  231020580
# 291                   別緊張臺東就沒有要被併校的問題\n\n請問有人知道臺東有大學嗎？     23  231020580
# 292  我跟你看法不太一樣，為了提升競爭力而提高入學門檻只會惡性競爭，因為現在年代資源充沛，提高門檻...     24  231020580
# 293                         併國北教真的不行 太店了==\n臺師和臺科我覺得可以     25  231020580
# 294  看到考上竹教的高中同學高調的把臉書學校改成清大就覺得不可置信\n怎麼會 \n到底為什麼二所分...     26  231020580
# 295  B26 \n我還真的有國中同學\n去填竹教 \n為了搭上併校順風車\n現在她都說她是114的...     27  231020580
# 296                  B27 清大教育系vs清大電機系\n我相信明眼人都知道哪個是仿的。     28  231020580
# 297               B28 \n不會啦\n很多沒接觸到這方面的聽到114\n還管你是哪個校區     29  231020580
# 298                            因為教育部動不了財團的私校唉，國立只好被當槍使     30  231020580
# 299  跟我們併校感覺好像獲益蠻多的（？\n不過我們有錢的是醫院啊\n我們根本名副其實的”中國醫藥醫...     31  231020580
# 300                                        B7 台南大學虎視眈眈     32  231020580
# 301  我也覺得很奇怪\n幹嘛不從一堆連聽都沒聽過的科大先剷除啊==\n清大併竹教\n中山併高大\n...     33  231020580
# 302  B33 輔大嘴高大？好像輪不到你們這種咖\n也不是每個高大的裝清高\n但不管有無裝清高\n好...     34  231020580
# 303                                       B33 哪來的臉嘴高大？     35  231020580
# 304  33樓講到最後還是露出差不多的嘴臉嘍🤔\n中山商管贏高大明明目前看起來都只有一個女生講，然後...     36  231020580
# 305                             不趕快把我們滅掉\n前段的一直併是在衝三小啦      1  231012507
# 306                                               恭喜高大      2  231012507
# 307                                  所以我都叫剛考完學測的高三生選高大      3  231012507
# 308                               中山也太衰\n缺法學院也不用隨便成這樣吧      4  231012507
# 309                      真的有夠雖\n尤其看那些高大的低端在那邊高潮\n就覺得很噁      5  231012507
# 310                                              幫中山QQ      6  231012507
# 311                                    什麼時候輪到我們跟中興併呢😆😆      7  231012507
# 312                                  交通大學什麼時候才要跟我們合併啊？      8  231012507
# 313  啊對了 B4 B5 B6 還有這個\nhttps://i.imgur.com/uXdBsDy...      9  231012507
# 314  學弟妹快利用轉學考和研究所離開學校，學校真的想錢想排名發瘋了雖然本來就是學店了。高雄已經夠慘...     10  231012507
# 315  下禮拜開始有一系列的併校說明會\n\n然後與此同時，高醫也要辦跟我們的併校說明會\n\n都不...     11  231012507
# 316            希望你們併完後的第一次畢業典禮不要出現奇怪的事\n像清大那次我真的是看了很感嘆     12  231012507
# 317                                    恭喜中山大學合併地名學店🎉🎉🎉     13  231012507
#
# [318 rows x 4 columns]
